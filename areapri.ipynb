# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import linear_model



# %matplotlib inline
# Out:
# Running cells with 'Python 3.9.1 ('.venv': venv)' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Home/OneDrive/Desktop/ds_lab/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
data=pd.read_excel("C:\\Users\\Home\\OneDrive\\Desktop\ds_lab\Book1.xlsx")
data
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
#ploting a scatter plot
plt.xlabel('area(sqr ft )')
plt.ylabel('price(us$)')
plt.scatter(data.area,data.price)

# %%
# reg =linear_model.LinearRegression()
# reg.fit(data[['area']],data.price)
x = data['area']
Y = data['price']

# %%
lm=linear_model.LinearRegression()
lm.fit(X=x.values.reshape(-1,1),y=Y.values.reshape(-1,1))
# Out:
# LinearRegression()

# %%
import pickle

# %%
pickle.dump(lm,open('model1.pkl','wb'))

# %%
model1 = pickle.load(open('model1.pkl','rb'))
